# %% [markdown]
# ## Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import Arc, Rectangle, ConnectionPatch
import seaborn as sns

# %% [markdown]
# ## Importando os chutes:

# %%
kick1=np.loadtxt( 'kick1.dat' )
kick1=pd.DataFrame(kick1)
kick2=np.loadtxt( 'kick2.dat' )
kick2=pd.DataFrame(kick2)
kick1.columns=['x','y','z']
kick2.columns=['x','y','z']

# %% [markdown]
# ## Função que imprime o campo:

# %%
def draw_pitch(ax,p):
    # size of the pitch is 120, 80
    #Create figure

    #Pitch Outline & Centre Line
    plt.plot([0*p,0*p],[-20*p,20*p], color="black")
    plt.plot([0*p,40*p],[20*p,20*p], color="black")
    plt.plot([40*p,40*p],[20*p,-20*p], color="black")
    plt.plot([40*p,0*p],[-20*p,-20*p], color="black")
    plt.plot([40*p,40*p],[-20*p,20*p], color="black")

    #Left Penalty Area
    plt.plot([14.6*p,14.6*p],[17.8*p,-17.5*p],color="black")
    plt.plot([0*p,14.6*p],[17.8*p,17.5*p],color="black")
    plt.plot([0*p,14.6*p],[-17.5*p,-17.5*p],color="black")

    #Left 6-yard Box
    plt.plot([0*p,4.9*p],[8*p,8*p],color="black")
    plt.plot([4.9*p,4.9*p],[8*p,-8*p],color="black")
    plt.plot([0*p,4.9*p],[-8*p,-8*p],color="black")

    #Prepare Circles
    centreCircle = Arc((45*p,0*p),height=16.2*p,width=16.2*p,angle=0,theta1=130,theta2=230,color="black")
    centreSpot = plt.Circle((40*p,0*p),0.71*p,color="black")
    leftPenSpot = plt.Circle((9.7*p,0*p),0.71*p,color="black")
    rightPenSpot = plt.Circle((110.3*p,0*p),0.71*p,color="black")

    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)


    #Prepare Arcs
    # arguments for arc
    # x, y coordinate of centerpoint of arc
    # width, height as arc might not be circle, but oval
    # angle: degree of rotation of the shape, anti-clockwise
    # theta1, theta2, start and end location of arc in degree
    leftArc = Arc((9.7*p,0*p),height=16.2*p,width=16.2*p,angle=0,theta1=310,theta2=50,color="black")
    

    #Draw Arcs
    ax.add_patch(leftArc)

# %%
'''Construindo o tempo para 20 posições da bola no chute, dado que os dados são capturados a uma taxa de 
60 frames por segundo. Ou seja, cada posição da bola leva 0.016666667 segundos para ser capturado'''
i=0
T=[]
x=0.016666667
y=0
while i<=19:
    y=y+x
    T.append(y)
    i+=1
kick1['t']=T
kick2['t']=T

# %% [markdown]
# ## Verificando os chutes no campo:

# %%
#eixos do kick1
X1=-kick1.x
Y1=kick1.y
Z1=kick1.z

#eixos do kick2
X2=-kick2.x
Y2=kick2.y
Z2=kick2.z

#plotando a figura dos kicks para os eixos x e y --> Notar que os eixos estão invertidos!!!
fig=plt.figure()
fig.set_size_inches(12, 7)
ax=fig.add_subplot(1,1,1)
draw_pitch(ax,0.33)
plt.scatter(Y1, X1)
plt.scatter(Y2, X2)
plt.show()

# %% [markdown]
# # Análise exploratória

# %%
# ANALISANDO OS EIXOS KICK 1

fig, axs = plt.subplots(3, 2)
fig.set_size_inches(12, 7)
# Axis 1
axs[0, 0].scatter(T, X1)
axs[0, 0].set(xlabel='t', ylabel='x1')
axs[0, 0].set_title("KICK1")
# Axis 2
axs[1, 0].scatter(T, Y1)
axs[1, 0].set(xlabel='t', ylabel='y1')
axs[1, 0].set_title("KICK1")
# Axis 3
axs[0, 1].scatter(T, Z1)
axs[0, 1].set(xlabel='t', ylabel='z1')
axs[0, 1].set_title("KICK1")
# Axis 4
axs[1, 1].scatter(T, X2)
axs[1, 1].set(xlabel='t', ylabel='x2')
axs[1, 1].set_title("KICK2")
# Axis 4
axs[2, 0].scatter(T, Y2)
axs[2, 0].set(xlabel='t', ylabel='y2')
axs[2, 0].set_title("KICK2")
# Axis 4
axs[2, 1].scatter(T, Z2)
axs[2, 1].set(xlabel='t', ylabel='z2')
axs[2, 1].set_title("KICK2")

fig.tight_layout()

# %%
kick1.describe()
# Out:
#                x          y          z          t
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.727700   1.576650   0.119600   0.175000
# std     0.294473   0.295319   0.014605   0.098601
# min    -1.192000   1.109000   0.103000   0.016667
# 25%    -0.974000   1.328750   0.109500   0.095833
# 50%    -0.742500   1.589500   0.114000   0.175000
# 75%    -0.519000   1.815500   0.128250   0.254167
# max    -0.210000   2.048000   0.149000   0.333333

# %%
kick2.describe()
# Out:
#                x          y          z          t
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.363200   1.576650   0.237800   0.175000
# std     0.146036   0.295319   0.047159   0.098601
# min    -0.596000   1.109000   0.145000   0.016667
# 25%    -0.491500   1.328750   0.207750   0.095833
# 50%    -0.361000   1.589500   0.247000   0.175000
# 75%    -0.257000   1.815500   0.280250   0.254167
# max    -0.105000   2.048000   0.296000   0.333333

# %%
sns.pairplot(kick1)

# %%
sns.pairplot(kick2)

# %% [markdown]
# # Modelo para kick 1

# %% [markdown]
# Devemos estabelecer um modelo de regressão para cada eixo, baseado no tempo.
# <br><br>
# $X=$ $\alpha_1*t$ + $\beta_1$ + $\epsilon$ <br>
# $Y=$ $\alpha_2*t$ + $\beta_2$ + $\epsilon$<br>
# $Z=$ $\alpha_3*t$ + $\beta_3$ + $\epsilon$

# %%
def cost_function(T,X,alpha,beta):
    '''MSE   RMSE'''
    x_hat_list=[]
    total_error=0.0
    N=len(T)
    for i in range(N):
        x_hat = alpha * T[i] + beta
        x_hat_list.append(x_hat)
        total_error += (X[i] - x_hat )**2
    mse = total_error/N
    rmse = np.sqrt(mse)
    return mse , rmse , x_hat_list


def update_weights(T,X,alpha,beta,learning_rate):
    alpha_deriv=0
    beta_deriv=0
    N=len(X)
    for i in range(N):
        alpha_deriv += -2*T[i] * (X[i] - (alpha*T[i] + beta))
        beta_deriv += -2 * (X[i] - (alpha*T[i] + beta))
    alpha -= (alpha_deriv / float(N)) * learning_rate
    beta -= (beta_deriv / float(N)) * learning_rate
    return alpha, beta

# %%
def fit(T, X, alpha, beta, learning_rate, iters):
    cost_history = []
    space_inter=iters/10
    for i in range(int(iters)):
        alpha,beta = update_weights(T, X, alpha, beta, learning_rate)

        #Calculate cost for auditing purposes
        mse,rmse,x_hat = cost_function(T, X, alpha, beta)
        cost_history.append(rmse)

        # Log Progress
        if i % space_inter == 0:
            print ("iter={:d}    alpha={:.2f}    beta={:.4f}    RMSE={:.2}".format(i, alpha, beta, rmse))
            plt.scatter(T,X)
            plt.plot(T,x_hat)
            plt.show()
    return alpha, beta, cost_history

# %% [markdown]
# ### Fitting X for kick1

# %%
alpha_1=0
beta_1=0
learning_rate=1e-2
inters=30000
alpha,beta,cost_history = fit(T,X1,alpha_1,beta_1,learning_rate,inters)
# Out:
# iter=0    alpha=0.00    beta=0.0146    RMSE=0.77
# iter=3000    alpha=1.31    beta=0.5011    RMSE=0.16
# iter=6000    alpha=2.00    beta=0.3789    RMSE=0.097
# iter=9000    alpha=2.41    beta=0.3076    RMSE=0.061
# iter=12000    alpha=2.64    beta=0.2659    RMSE=0.042
# iter=15000    alpha=2.78    beta=0.2415    RMSE=0.033
# iter=18000    alpha=2.86    beta=0.2273    RMSE=0.029
# iter=21000    alpha=2.91    beta=0.2190    RMSE=0.028
# iter=24000    alpha=2.93    beta=0.2142    RMSE=0.027
# iter=27000    alpha=2.95    beta=0.2113    RMSE=0.027

# %%
plt.show()

# %%
inter=list(range(0,inters))
plt.plot(inter,cost_history)
plt.show()

# %% [markdown]
# ### Fitting Y for kick1

# %%
alpha_1=0
beta_1=0
learning_rate=1e-2
alpha,beta,cost_history = fit(T,Y1,alpha_1,beta_1,learning_rate,inters)
# Out:
# iter=0    alpha=0.00    beta=0.0315    RMSE=1.6
# iter=3000    alpha=-1.09    beta=1.7640    RMSE=0.18
# iter=6000    alpha=-1.88    beta=1.9039    RMSE=0.11
# iter=9000    alpha=-2.34    beta=1.9856    RMSE=0.063
# iter=12000    alpha=-2.61    beta=2.0334    RMSE=0.038
# iter=15000    alpha=-2.77    beta=2.0613    RMSE=0.024
# iter=18000    alpha=-2.86    beta=2.0775    RMSE=0.016
# iter=21000    alpha=-2.92    beta=2.0871    RMSE=0.013
# iter=24000    alpha=-2.95    beta=2.0926    RMSE=0.012
# iter=27000    alpha=-2.97    beta=2.0959    RMSE=0.011

# %%
inter=list(range(0,inters))
plt.plot(inter,cost_history)
plt.show()

# %% [markdown]
# ### Fitting Z for kick1

# %%
alpha_1=0
beta_1=0
learning_rate=1e-2
alpha,beta,cost_history = fit(T,Z1,alpha_1,beta_1,learning_rate,inters)
# Out:
# iter=0    alpha=0.00    beta=0.0024    RMSE=0.12
# iter=3000    alpha=-0.00    beta=0.1196    RMSE=0.014
# iter=6000    alpha=-0.01    beta=0.1218    RMSE=0.014
# iter=9000    alpha=-0.02    beta=0.1230    RMSE=0.014
# iter=12000    alpha=-0.02    beta=0.1237    RMSE=0.014
# iter=15000    alpha=-0.03    beta=0.1242    RMSE=0.014
# iter=18000    alpha=-0.03    beta=0.1244    RMSE=0.014
# iter=21000    alpha=-0.03    beta=0.1246    RMSE=0.014
# iter=24000    alpha=-0.03    beta=0.1247    RMSE=0.014
# iter=27000    alpha=-0.03    beta=0.1247    RMSE=0.014
