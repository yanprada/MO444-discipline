# %% [markdown]
# # Tarefa 2 - Parte 1
# MO444A - Aprendizado de Máquina e Reconhecimento de Padrões
#
# > Aplicação de métodos de aprendizado supervisionado para resolver problemas de predição e classificação
#
# __Alunos:__
# - Leonardo Augusto Silva Bernardes - RA: 233548 <br>
# Desenvolveu a parte 2 do trabalho. <br>
# <br><br>
# - Yan Prada - RA: 118982<br>
# Desenvolveu a parte 1 do trabalho
# <br><br>

# %% [markdown]
# ## Discussão e principais conclusões
#
# Decidimos trazer os principais resultados para o início do trabalho, dado o tamanho extenso do notebook. Primeiro, estabelecemos as Funções de Regressão, tanto Linear como Polinomial, com os eixos como variáveis dependentes e o tempo como variável indepedente. A seguir mostramos cada Equação:
# <br><br><br>
# <b>Regressão Linear: </b>
# <br><br>
# $X=$ $\alpha_1*t$ + $\beta_1$ + $\epsilon$<br>
# $Y=$ $\alpha_2*t$ + $\beta_2$ + $\epsilon$<br>
# $Z=$ $\alpha_3*t$ + $\beta_3$ + $\epsilon$
# <br>  <br>
# <b>Regressão Polinomial: </b>
# <br>
# $X=$ $\gamma_1*t²$ + $\alpha_1*t$ + $\beta_1$ + $\epsilon$<br>
# $Y=$ $\alpha_2*t$ + $\beta_2$ + $\epsilon$<br>
# $Z=$ $\gamma_3*t²$ + $\alpha_3*t$ + $\beta_3$ + $\epsilon$
# <br><br><br>
# Após a implementação da função de descida do gradiente para minimizar a função custo, dada por $\epsilon$, adotamos o Learning Rate de 1e-2 e número de interações igual a 30.000. Para esses hiperparâmetros, encontramos os seguintes valores para os $\alpha's$ e $\beta's$ de cada equação:
#
# <br>
# <b>Regressão Linear: </b><br><br>
# <ul>
# <li> Kick 1:
# <br><br>
# $X=$ $-2.96*t$ - $0.21$ <br>
# $Y=$ $-2.98*t$ + $2.1$ <br>
# $Z=$ $-0.03*t$ + $0.12$
# <br>  <br> </li>
# <li>Kick 2:
# <br><br>
# $X=$ $-1.47*t$ - $0.11$ <br>
# $Y=$ $-2.98*t$ + $2.1$ <br>
# $Z=$ $0.44*t$ + $0.16$
# <br>  <br></li>
# </ul>
#
# <b>Regressão Polinomial: </b> <br>
#
# <ul>
# <li>Kick 1:
# <br><br>
# $X=$ $-0.95*t²$ - $3.31*t$ - $0.19$ <br>
# $Y=$ $-2.98*t$ + $2.1$ <br>
# $Z=$ $0.25*t²$ - $0.12*t$ + $0.13$
# <br>  <br></li>
# <li>Kick 2:
# <br><br>
# $X=$ $0.45*t²$ - $1.63*t$ - $0.1$ <br>
# $Y=$ $-2.98*t$ + $2.1$ <br>
# $Z=$ $-1.02*t²$ + $0.8*t$ + $0.14$
# <br>  <br></li>
# </ul>
# Não adotamos uma equação polinomial para o eixo Y pois, pensando no fenômeno físico do chute, é muito difícil não ser um movimento retilíneo para o eixo Y. Comparando os erros de nossa Função de Regressão Populacional (FRP), entre a Linear e a Polinomial, fica claro que a função polinomial reduziu mais o erro, sob a métrica da raiz quadrada do erro médio (RMSE em inglês). Abaixo postamos os erros encontrados em cada Função de Regressão para cada chute.
#
# <b>Análise dos Erros pela métrica que RMSE: </b> <br>
# <ul>
# <li><b>KICK 1: </b>
# <br><br>
# Linear:<br>
# <ul>
#     <li>
#     $RMSE_X= 0.027$
# </li>
#     <li>
#     $RMSE_Y= 0.011$
# </li>
#     <li>
#     $RMSE_Z= 0.014$
# </li>
# </ul><br>
# Polinomial: <br>
# <ul>
#     <li>
#     $RMSE_X= 0.024$
# </li>
#     <li>
#     $RMSE_Y= 0.011$
# </li>
#     <li>
#     $RMSE_Z= 0.014$
# </li>
# </ul>
# <br>  <br></li>
# <li><b>KICK 2: </b>
# <br><br>
# Linear:<br>
# <ul>
#     <li>
#     $RMSE_X= 0.016$
# </li>
#     <li>
#     $RMSE_Y= 0.011$
# </li>
#     <li>
#     $RMSE_Z= 0.017$
# </li>
# </ul><br>
# Polinomial: <br>
# <ul>
#     <li>
#     $RMSE_X= 0.014$
# </li>
#     <li>
#     $RMSE_Y= 0.011$
# </li>
#     <li>
#     $RMSE_Z= 0.012$
# </li>
# </ul>
# <br>  <br></li>
# </ul>
#
# Fica claro que, principalmente para o eixo Z do kick2, o erro foi reduzido significativamente ao implementarmos a função de regressão polinomial.
#
# Também, como mostramos no final do notebook, se adotarmos um learning rate muito baixo para a função de descida do gradiente, nosso algoritmo demora muito para encontrar o mínimo da função de custo. De maneira oposta, se adotarmos um learning rate muito grande, nossa função diverge, explodindo o valor dos parâmetros até dar overflow.
#
# Abaixo mostramos os gráficos das previsões feitas pelos nossos modelos:
# <img src="assets/3d_view.jpg">
# Nesse gráfico 3D, podemos perceber que o chute do kick2 para a função linear iria continuar um trajetória ascendente. Já para a função polinomial de grau 2 a bola faz uma curva. Tentamos implemtar uma função para Z levando em conta  a aceleração da força a gravidade, mas o modelo não estimou bem os dados da bola. Por isso decidimos deixar que o algoritmo decidisse o valor do parâmetro $\gamma$ nas equações polinomiais.
#
# Decompomos o gráfico 3D nos subgráficos 2D abaixo:
# <img src="assets/2d_view.jpg">
# <img src="assets/field_view.jpg">
# Para a discussão sobre se eu seria capaz de defender o chute, é claro que isso necessitaria uma análise mais refinada, porém, faremos aqui uma análise resumida. A altura da bola não seria tão difícil de defender, pois não chega nem a um metro de altura. Porém, a distância de X é o problema, principalmente para o chute 2. Eu teria um tempo muito curto de reação, algo em torno de menos de 2/3 de segundos, para caminhar uma distância de 1 metro para o chute 1 e de 2 metros para o chute 2. Tavez se eu esticasse a perna, daria para defender o chute 1. Porém o chute 2 eu teria que me jogar, e não tenho habilidade para isso, portanto possivelmente não alcançaria a bola a tempo.

# %% [markdown]
# # Início do Trabalho Parte 1

# %% [markdown]
# ## Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import Arc, Rectangle, ConnectionPatch
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Importando os chutes:

# %%
kick1=np.loadtxt( 'kick1.dat' )
kick1=pd.DataFrame(kick1)
kick2=np.loadtxt( 'kick2.dat')
kick2=pd.DataFrame(kick2)
kick1.columns=['x','y','z']
kick2.columns=['x','y','z']

# %% [markdown]
# ## Função que imprime o campo:

# %%
def draw_pitch(ax,p):
    # size of the pitch is 120, 80
    #Create figure

    #Pitch Outline & Centre Line
    plt.plot([0*p,0*p],[-20*p,20*p], color="black")
    plt.plot([0*p,40*p],[20*p,20*p], color="black")
    plt.plot([40*p,40*p],[20*p,-20*p], color="black")
    plt.plot([40*p,0*p],[-20*p,-20*p], color="black")
    plt.plot([40*p,40*p],[-20*p,20*p], color="black")

    #Left Penalty Area
    plt.plot([14.6*p,14.6*p],[17.8*p,-17.5*p],color="black")
    plt.plot([0*p,14.6*p],[17.8*p,17.5*p],color="black")
    plt.plot([0*p,14.6*p],[-17.5*p,-17.5*p],color="black")

    #Left 6-yard Box
    plt.plot([0*p,4.9*p],[8*p,8*p],color="black")
    plt.plot([4.9*p,4.9*p],[8*p,-8*p],color="black")
    plt.plot([0*p,4.9*p],[-8*p,-8*p],color="black")

    #Prepare Circles
    centreCircle = Arc((45*p,0*p),height=16.2*p,width=16.2*p,angle=0,theta1=130,theta2=230,color="black")
    centreSpot = plt.Circle((40*p,0*p),0.71*p,color="black")
    leftPenSpot = plt.Circle((9.7*p,0*p),0.71*p,color="black")
    rightPenSpot = plt.Circle((110.3*p,0*p),0.71*p,color="black")

    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)


    #Prepare Arcs
    # arguments for arc
    # x, y coordinate of centerpoint of arc
    # width, height as arc might not be circle, but oval
    # angle: degree of rotation of the shape, anti-clockwise
    # theta1, theta2, start and end location of arc in degree
    leftArc = Arc((9.7*p,0*p),height=16.2*p,width=16.2*p,angle=0,theta1=310,theta2=50,color="black")
    

    #Draw Arcs
    ax.add_patch(leftArc)

# %%
'''Construindo o tempo para 20 posições da bola no chute, dado que os dados são capturados a uma taxa de 
60 frames por segundo. Ou seja, cada posição da bola leva 0.016666667 (1/60) segundos para ser capturado'''
i=0
T_full=[]
x=0.016666667
y=0
while i<=60:
    y=y+x
    T_full.append(y)
    i+=1
T=T_full[:20]

kick1['t']=T
kick2['t']=T

# %% [markdown]
# ## Verificando os chutes no campo:

# %%
#eixos do kick1
X1=kick1.x
Y1=kick1.y
Z1=kick1.z

#eixos do kick2
X2=kick2.x
Y2=kick2.y
Z2=kick2.z


#plotando a figura dos kicks para os eixos x e y --> Notar que os eixos estão invertidos!!!
fig=plt.figure()
fig.set_size_inches(12, 7)
ax=fig.add_subplot(1,1,1)
draw_pitch(ax,0.33)
plt.scatter(Y1, X1,label='kick1')
plt.scatter(Y2, X2,label='kick2')
plt.legend()
ax.invert_yaxis()
plt.show()

# %% [markdown]
# # Análise exploratória
# No gráfico abaixo analisamos as variáveis em relação ao tempo. Porém podemos considerar também o eixo y como independente, dado que sabemos que a bola vai realizar a trajetória de y=2.1 até y=0.

# %%
# ANALISANDO OS EIXOS KICK 1

fig, axs = plt.subplots(2, 2)
fig.set_size_inches(12, 7)
# Axis 1
axs[0, 0].scatter(T, X1,label='kick1')
axs[0, 0].scatter(T, X2,label='kick2')
axs[0, 0].set(xlabel='t', ylabel='x1 and x2')
axs[0, 0].set_title("KICK1 and KICK2")
axs[0, 0].legend()

# Axis 2
axs[1, 0].scatter(T, Y1,label='kick1')
axs[1, 0].scatter(T, Y2,label='kick2')
axs[1, 0].set(xlabel='t', ylabel='y1=y2')
axs[1, 0].set_title("KICK1 and KICK2")
axs[1, 0].legend()

# Axis 3
axs[0, 1].scatter(T, Z1,label='kick1')
axs[0, 1].scatter(T, Z2,label='kick2')
axs[0, 1].set(xlabel='t', ylabel='z1 and z2')
axs[0, 1].set_title("KICK1 and KICK2")
axs[0, 1].legend()

fig.tight_layout()

# %%
kick1.describe()
# Out:
#                x          y          z          t
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.727700   1.576650   0.119600   0.175000
# std     0.294473   0.295319   0.014605   0.098601
# min    -1.192000   1.109000   0.103000   0.016667
# 25%    -0.974000   1.328750   0.109500   0.095833
# 50%    -0.742500   1.589500   0.114000   0.175000
# 75%    -0.519000   1.815500   0.128250   0.254167
# max    -0.210000   2.048000   0.149000   0.333333

# %%
kick2.describe()
# Out:
#                x          y          z          t
# count  20.000000  20.000000  20.000000  20.000000
# mean   -0.363200   1.576650   0.237800   0.175000
# std     0.146036   0.295319   0.047159   0.098601
# min    -0.596000   1.109000   0.145000   0.016667
# 25%    -0.491500   1.328750   0.207750   0.095833
# 50%    -0.361000   1.589500   0.247000   0.175000
# 75%    -0.257000   1.815500   0.280250   0.254167
# max    -0.105000   2.048000   0.296000   0.333333

# %%
sns.pairplot(kick1)

# %%
sns.pairplot(kick2)

# %% [markdown]
# # Construindo o modelo de Regressão Linear

# %% [markdown]
# ## CONSIDERANDO O TEMPO COMO VARIÁVEL INDEPEDENTE
# Nesse caso, consideramos que o tempo é a variável independente e cada eixo varia conforme o passar do tempo. Isso permite um modelo mais reativo com a espera do goleiro para tomar uma reação frente ao chute

# %% [markdown]
# ## Equações:

# %% [markdown]
# Devemos estabelecer um modelo de regressão para cada eixo, baseado no tempo.
# <br><br>
# $X=$ $\alpha_1*t$ + $\beta_1$ + $\epsilon$<br>
# $Y=$ $\alpha_2*t$ + $\beta_2$ + $\epsilon$<br>
# $Z=$ $\alpha_3*t$ + $\beta_3$ + $\epsilon$

# %% [markdown]
# ### Definindo as funções de custo, de pesos e de fit_linear

# %%
def cost_function(T,X,alpha,beta):
    '''MSE   RMSE'''
    x_hat_list=[]
    total_error=0.0
    N=len(X)
    for i in range(N):
        x_hat = alpha * T[i] + beta
        x_hat_list.append(x_hat)
        total_error += (X[i] - x_hat )**2
    mse = total_error/N
    rmse = np.sqrt(mse)
    return mse , rmse , x_hat_list


def update_weights(T,X,alpha,beta,learning_rate):
    alpha_deriv=0
    beta_deriv=0
    N=len(X)
    for i in range(N):
        alpha_deriv += -2*T[i] * (X[i] - (alpha*T[i] + beta))
        beta_deriv += -2 * (X[i] - (alpha*T[i] + beta))
    alpha -= (alpha_deriv / float(N)) * learning_rate
    beta -= (beta_deriv / float(N)) * learning_rate
    return alpha, beta



def fit_linear(T, X, alpha, beta, learning_rate, iters):
    cost_history = []
    space_inter=iters/5
    mse_fim=0
    rmse_fim=0
    for i in range(int(iters)):
        alpha,beta = update_weights(T, X, alpha, beta, learning_rate)

        #Calculate cost for auditing purposes
        mse_ini,rmse_ini,x_hat = cost_function(T, X, alpha, beta)
        cost_history.append(rmse_ini)
        
        #Checking for the tolerance of the error
        tol_rmse = np.abs(rmse_ini-rmse_fim)
        tol_mse = np.abs(mse_ini-mse_fim)
        if tol_rmse < 1e-10:
            break
        mse_fim=mse_ini
        rmse_fim=rmse_ini
        
        # Log Progress
        if i % space_inter == 0:
            print ("iter={:d}    alpha={:.2f}    beta={:.4f}    MSE={:.2}     RMSE={:.2}".format(i, alpha, beta, mse_fim, rmse_fim))
            plt.scatter(T,X)
            plt.plot(T,x_hat,c='red')
            plt.show()
    return rmse_fim, alpha, beta, cost_history, i

# %% [markdown]
# ### Definindo as variáveis globais

# %%
gamma_fixo= -9.8

gamma_inicial= 0
alpha_inicial=0
beta_inicial=0

learning_rate=1e-2
inters=30000

# %% [markdown]
# ## KICK 1

# %% [markdown]
# ### Fitting X for kick1

# %%
rmse1_K1_lin, alpha1_K1_lin,beta1_K1_lin,cost_history1_K1_lin,end_inter1_K1_lin = fit_linear(T,X1,alpha_inicial,beta_inicial,learning_rate,inters)
# Out:
# iter=0    alpha=-0.00    beta=-0.0146    MSE=0.59     RMSE=0.77
# iter=6000    alpha=-2.00    beta=-0.3789    MSE=0.0094     RMSE=0.097
# iter=12000    alpha=-2.64    beta=-0.2659    MSE=0.0017     RMSE=0.042
# iter=18000    alpha=-2.86    beta=-0.2273    MSE=0.00084     RMSE=0.029
# iter=24000    alpha=-2.93    beta=-0.2142    MSE=0.00073     RMSE=0.027

# %%
inter=list(range(0,end_inter1_K1_lin))
plt.plot(inter[:500],cost_history1_K1_lin[:500])
plt.xlabel('Interações')
plt.ylabel('RMSE')
plt.title('Gráfico do custo por número interações'.upper())
plt.show()

# %% [markdown]
# O gráfico dos valores d RMSE pelo total de interações nos mostra que nosso modelo, com cerca de 100 interações, reduz drasticamente o RMSE. Depois disso, a diminuição do erro é marginal.

# %% [markdown]
# ### Fitting Y for kick1

# %%
rmse2_K1_lin, alpha2_K1_lin,beta2_K1_lin,cost_history2_K1_lin,end_inter2_K1_lin = fit_linear(T,Y1,alpha_inicial,beta_inicial,learning_rate,inters)
# Out:
# iter=0    alpha=0.00    beta=0.0315    MSE=2.5     RMSE=1.6
# iter=6000    alpha=-1.88    beta=1.9039    MSE=0.012     RMSE=0.11
# iter=12000    alpha=-2.61    beta=2.0334    MSE=0.0014     RMSE=0.038
# iter=18000    alpha=-2.86    beta=2.0775    MSE=0.00027     RMSE=0.016
# iter=24000    alpha=-2.95    beta=2.0926    MSE=0.00013     RMSE=0.012

# %%
inter=list(range(0,end_inter2_K1_lin+1))
plt.plot(inter[:500],cost_history2_K1_lin[:500])
plt.xlabel('Interações')
plt.ylabel('RMSE')
plt.title('Gráfico do custo por número interações'.upper())
plt.show()

# %% [markdown]
# O gráfico dos valores d RMSE pelo total de interações nos mostra que nosso modelo, com cerca de 100 interações, reduz drasticamente o RMSE. Depois disso, a diminuição do erro é marginal.

# %% [markdown]
# ### Fitting Z for kick1

# %%
rmse3_K1_lin, alpha3_K1_lin,beta3_K1_lin,cost_history3_K1_lin,end_inter3_K1_lin = fit_linear(T,Z1,alpha_inicial,beta_inicial,learning_rate,inters)
# Out:
# iter=0    alpha=0.00    beta=0.0024    MSE=0.014     RMSE=0.12
# iter=6000    alpha=-0.01    beta=0.1218    MSE=0.0002     RMSE=0.014
# iter=12000    alpha=-0.02    beta=0.1237    MSE=0.00019     RMSE=0.014
# iter=18000    alpha=-0.03    beta=0.1244    MSE=0.00019     RMSE=0.014

# %%
inter=list(range(0,end_inter3_K1_lin+1))
plt.plot(inter[:500],cost_history3_K1_lin[:500])
plt.xlabel('Interações')
plt.ylabel('RMSE')
plt.title('Gráfico do custo por número interações'.upper())
plt.show()

# %% [markdown]
# O gráfico dos valores d RMSE pelo total de interações nos mostra que nosso modelo, com cerca de 100 interações, reduz drasticamente o RMSE. Depois disso, a diminuição do erro é marginal.

# %% [markdown]
# ### Equações finais para Kick1 modelo de regressão linear

# %%
print('X = {:.2f} * t + {:.2f}'.format(alpha1_K1_lin,beta1_K1_lin))
print('Y = {:.2f} * t + {:.2f}'.format(alpha2_K1_lin,beta2_K1_lin))
print('Z = {:.2f} * t + {:.2f}'.format(alpha3_K1_lin,beta3_K1_lin))
print('Erros para Kick1 Linear: RMSE_X={:.3f}, RMSE_Y={:.3f}, RMSE_Z={:.3f}'.format(rmse1_K1_lin,rmse2_K1_lin,rmse3_K1_lin))
# Out:
# X = -2.96 * t + -0.21
# Y = -2.98 * t + 2.10
# Z = -0.03 * t + 0.12
# Erros para Kick1 Linear: RMSE_X=0.027, RMSE_Y=0.011, RMSE_Z=0.014

# %% [markdown]
# ## KICK 2

# %% [markdown]
# ### Fitting X for kick2

# %%
rmse1_K2_lin, alpha1_K2_lin,beta1_K2_lin,cost_history1_K2_lin,end_inter1_K2_lin = fit_linear(T,X2,alpha_inicial,beta_inicial,learning_rate,inters)
# Out:
# iter=0    alpha=-0.00    beta=-0.0073    MSE=0.15     RMSE=0.38
# iter=6000    alpha=-0.99    beta=-0.1905    MSE=0.0024     RMSE=0.049
# iter=12000    alpha=-1.31    beta=-0.1346    MSE=0.0005     RMSE=0.022
# iter=18000    alpha=-1.42    beta=-0.1155    MSE=0.00028     RMSE=0.017
# iter=24000    alpha=-1.45    beta=-0.1090    MSE=0.00025     RMSE=0.016

# %%
inter=list(range(0,end_inter1_K2_lin+1))
plt.plot(inter[:500],cost_history1_K2_lin[:500])
plt.xlabel('Interações')
plt.ylabel('RMSE')
plt.title('Gráfico do custo por número interações'.upper())
plt.show()

# %% [markdown]
# O gráfico dos valores d RMSE pelo total de interações nos mostra que nosso modelo, com cerca de 100 interações, reduz drasticamente o RMSE. Depois disso, a diminuição do erro é marginal.

# %% [markdown]
# ### Fitting Y for kick2

# %%
rmse2_K2_lin, alpha2_K2_lin,beta2_K2_lin,cost_history2_K2_lin,end_inter2_K2_lin = fit_linear(T,Y2,alpha_inicial,beta_inicial,learning_rate,inters)
# Out:
# iter=0    alpha=0.00    beta=0.0315    MSE=2.5     RMSE=1.6
# iter=6000    alpha=-1.88    beta=1.9039    MSE=0.012     RMSE=0.11
# iter=12000    alpha=-2.61    beta=2.0334    MSE=0.0014     RMSE=0.038
# iter=18000    alpha=-2.86    beta=2.0775    MSE=0.00027     RMSE=0.016
# iter=24000    alpha=-2.95    beta=2.0926    MSE=0.00013     RMSE=0.012

# %%
inter=list(range(0,end_inter2_K2_lin+1))
plt.plot(inter[:500],cost_history2_K2_lin[:500])
plt.xlabel('Interações')
plt.ylabel('RMSE')
plt.title('Gráfico do custo por número interações'.upper())
plt.show()

# %% [markdown]
# O gráfico dos valores d RMSE pelo total de interações nos mostra que nosso modelo, com cerca de 100 interações, reduz drasticamente o RMSE. Depois disso, a diminuição do erro é marginal.

# %% [markdown]
# ### Fitting Z for kick2

# %%
rmse3_K2_lin, alpha3_K2_lin,beta3_K2_lin,cost_history3_K2_lin,end_inter3_K2_lin = fit_linear(T,Z2,alpha_inicial,beta_inicial,learning_rate,inters)
# Out:
# iter=0    alpha=0.00    beta=0.0048    MSE=0.056     RMSE=0.24
# iter=6000    alpha=0.31    beta=0.1844    MSE=0.00047     RMSE=0.022
# iter=12000    alpha=0.40    beta=0.1684    MSE=0.00031     RMSE=0.018
# iter=18000    alpha=0.43    beta=0.1629    MSE=0.00029     RMSE=0.017
# iter=24000    alpha=0.44    beta=0.1611    MSE=0.00029     RMSE=0.017

# %%
inter=list(range(0,end_inter3_K2_lin+1))
plt.plot(inter[:500],cost_history3_K2_lin[:500])
plt.xlabel('Interações')
plt.ylabel('RMSE')
plt.title('Gráfico do custo por número interações'.upper())
plt.show()

# %% [markdown]
# O gráfico dos valores d RMSE pelo total de interações nos mostra que nosso modelo, com cerca de 100 interações, reduz drasticamente o RMSE. Depois disso, a diminuição do erro é marginal.

# %% [markdown]
# ### Equações finais para Kick2 modelo de regressão linear

# %%
print('X = {:.2f} * t + {:.2f}'.format(alpha1_K2_lin,beta1_K2_lin))
print('Y = {:.2f} * t + {:.2f}'.format(alpha2_K2_lin,beta2_K2_lin))
print('Z = {:.2f} * t + {:.2f}'.format(alpha3_K2_lin,beta3_K2_lin))
print('Erros para Kick2 Linear: RMSE_X={:.3f}, RMSE_Y={:.3f}, RMSE_Z={:.3f}'.format(rmse1_K2_lin,rmse2_K2_lin,rmse3_K2_lin))
# Out:
# X = -1.47 * t + -0.11
# Y = -2.98 * t + 2.10
# Z = 0.44 * t + 0.16
# Erros para Kick2 Linear: RMSE_X=0.016, RMSE_Y=0.011, RMSE_Z=0.017

# %% [markdown]
# ## PREDIÇÃO KICK1 E KICK2 DADOS MODELOS DE REGRESSAO LINEAR

# %%
#eixos do kick1
X1_pred_lin=[]
X2_pred_lin=[]
Y1_pred_lin=[]
Y2_pred_lin=[]
Z1_pred_lin=[]
Z2_pred_lin=[]
for i in range(len(T_full)):
    X1_pred_lin.append((alpha1_K1_lin * T_full[i] + beta1_K1_lin))
    X2_pred_lin.append((alpha1_K2_lin * T_full[i] + beta1_K2_lin))
    Y1_pred_lin.append(alpha2_K1_lin * T_full[i] + beta2_K1_lin)
    Y2_pred_lin.append(alpha2_K2_lin * T_full[i] + beta2_K2_lin)
    Z1_pred_lin.append(alpha3_K1_lin * T_full[i] + beta3_K1_lin)
    Z2_pred_lin.append(alpha3_K2_lin * T_full[i] + beta3_K2_lin)
    if Y1_pred_lin[i]<=0:
        break




#plotando a figura dos kicks para os eixos x e y --> Notar que os eixos estão invertidos!!!
fig=plt.figure()
fig.set_size_inches(12, 7)
ax=fig.add_subplot(1,1,1)
draw_pitch(ax,0.33)
plt.scatter(Y1, X1,label='kick1')
plt.scatter(Y2, X2,label='kick2')
plt.plot(Y1_pred_lin, X1_pred_lin,label='predict kick1')
plt.plot(Y2_pred_lin, X2_pred_lin,label='predict kick2')
plt.legend()
ax.invert_yaxis()
plt.show()

# %% [markdown]
# # Construindo o modelo de Regressão Polinomial
#
# ## 1) CONSIDERANDO GRAVIDADE DE 9.8m/s² PARA FUNÇÃO QUADRÁDICA

# %% [markdown]
# ## Equações:

# %% [markdown]
# Devemos estabelecer um modelo de regressão para cada eixo, baseado no tempo.
# <br><br>
# $X=$ $\alpha_1*t$ + $\beta_1$ + $\epsilon$<br>
# $Y=$ $\alpha_2*t$ + $\beta_2$ + $\epsilon$<br>
# $Z=$ $\gamma_3*t²$ + $\alpha_3*t$ + $\beta_3$ + $\epsilon$, where $\gamma_3$ = -9.8 m/s²

# %% [markdown]
# ### Definindo as funções de pesos e de fit_polinomial_grav

# %%
def cost_function_pol_grav(T,X,gamma,alpha,beta):
    '''MSE   RMSE'''
    x_hat_list=[]
    total_error=0.0
    N=len(X)
    for i in range(N):
        x_hat = gamma * T[i]**2 + alpha * T[i] + beta
        x_hat_list.append(x_hat)
        total_error += (X[i] - x_hat )**2
    mse = total_error/N
    rmse = np.sqrt(mse)
    return mse , rmse , x_hat_list


def update_weights_pol_grav(T,X,gamma, alpha,beta,learning_rate):
    alpha_deriv=0
    beta_deriv=0
    N=len(X)
    for i in range(N):
        alpha_deriv += -2*T[i] * (X[i] - (gamma * T[i]**2 + alpha*T[i] + beta))
        beta_deriv += -2 * (X[i] - (gamma * T[i]**2 + alpha*T[i] + beta))
    alpha -= (alpha_deriv / float(N)) * learning_rate
    beta -= (beta_deriv / float(N)) * learning_rate
    return alpha, beta



def fit_polinomial_grav(T, X, gamma, alpha, beta, learning_rate, iters):
    cost_history = []
    space_inter=iters/5
    mse_fim=0
    rmse_fim=0
    for i in range(int(iters)):
        alpha,beta = update_weights_pol_grav(T, X, gamma, alpha, beta, learning_rate)

        #Calculate cost for auditing purposes
        mse_ini,rmse_ini,x_hat = cost_function_pol_grav(T, X, gamma, alpha, beta)
        cost_history.append(rmse_ini)
        
        #Checking for the tolerance of the error
        tol_rmse = np.abs(rmse_ini-rmse_fim)
        tol_mse = np.abs(mse_ini-mse_fim)
        if tol_rmse < 1e-10:
            break
        mse_fim=mse_ini
        rmse_fim=rmse_ini
        
        # Log Progress
        if i % space_inter == 0:
            print ("iter={:d}  gamma={:.2f}  alpha={:.2f}    beta={:.4f}    MSE={:.2}     RMSE={:.2}".format(i,gamma, alpha, beta, mse_fim, rmse_fim))
            plt.scatter(T,X)
            plt.plot(T,x_hat,c='red')
            plt.show()
    return alpha, beta, cost_history, i

# %%
alpha3_K2_grav,beta3_K2_grav,cost_history3_K2_grav,end_inter3_K2_grav = fit_polinomial_grav(T,Z2,gamma_fixo,alpha_inicial,beta_inicial,learning_rate,inters)
# Out:
# iter=0  gamma=-9.80  alpha=0.00    beta=0.0126    MSE=0.52     RMSE=0.72
# iter=6000  gamma=-9.80  alpha=2.59    beta=0.1773    MSE=0.02     RMSE=0.14
# iter=12000  gamma=-9.80  alpha=3.44    beta=0.0279    MSE=0.0066     RMSE=0.081
# iter=18000  gamma=-9.80  alpha=3.72    beta=-0.0231    MSE=0.005     RMSE=0.071
# iter=24000  gamma=-9.80  alpha=3.82    beta=-0.0405    MSE=0.0048     RMSE=0.07

# %%
inter=list(range(0,end_inter3_K2_grav+1))
plt.plot(inter[:500],cost_history3_K2_grav[:500])
plt.xlabel('Interações')
plt.ylabel('RMSE')
plt.title('Gráfico do custo por número interações'.upper())
plt.show()

# %% [markdown]
# O gráfico dos valores d RMSE pelo total de interações nos mostra que nosso modelo, com cerca de 100 interações, reduz drasticamente o RMSE. Depois disso, a diminuição do erro é marginal. Entretanto, como vemos na imagem acima do gráfico do erro, nosso modelo não se encaixou bem aos dados, pois fixamos o valor da aceleração para a gravidade, em 9.8m/s². Entretanto, há outros fatores que contribuem para o comportamento da bola, como por exemplo a resistência do ar. Talvez por isso fixar um valor não seja uma boa para o ajuste da nossa função de regressão aos dados.

# %% [markdown]
# ## 2) DEIXANDO O SISTEMA DEFINIR O GAMMA PARA FUNÇÃO QUADRÁDICA

# %% [markdown]
# ## Equações:

# %% [markdown]
# Devemos estabelecer um modelo de regressão para cada eixo, baseado no tempo.
# <br><br>
# $X=$ $\gamma_1*t²$ + $\alpha_1*t$ + $\beta_1$ + $\epsilon$<br>
# $Y=$ $\alpha_2*t$ + $\beta_2$ + $\epsilon$<br>
# $Z=$ $\gamma_3*t²$ + $\alpha_3*t$ + $\beta_3$ + $\epsilon$

# %% [markdown]
# ### Definindo as funções de pesos e de fit_polinomial_quadr

# %%
def cost_function_pol_quadr(T,X,gamma,alpha,beta):
    '''MSE   RMSE'''
    x_hat_list=[]
    total_error=0.0
    N=len(X)
    for i in range(N):
        x_hat = gamma * T[i]**2 + alpha * T[i] + beta
        x_hat_list.append(x_hat)
        total_error += (X[i] - x_hat )**2
    mse = total_error/N
    rmse = np.sqrt(mse)
    return mse , rmse , x_hat_list


def update_weights_pol_quadr(T,X,gamma, alpha,beta,learning_rate):
    
    gamma_deriv=0
    alpha_deriv=0
    beta_deriv=0
    
    N=len(X)
    for i in range(N):
        gamma_deriv += -2 *(T[i]**2) * (X[i] - (gamma * T[i]**2 + alpha*T[i] + beta))
        alpha_deriv += -2*T[i] * (X[i] - (gamma * T[i]**2 + alpha*T[i] + beta))
        beta_deriv += -2 * (X[i] - (gamma * T[i]**2 + alpha*T[i] + beta))
    gamma -= (gamma_deriv / float(N)) * learning_rate
    alpha -= (alpha_deriv / float(N)) * learning_rate
    beta -= (beta_deriv / float(N)) * learning_rate
    return gamma, alpha, beta



def fit_polinomial_quadr(T, X, gamma, alpha, beta, learning_rate, iters):
    cost_history = []
    space_inter=iters/5
    mse_fim=0
    rmse_fim=0
    for i in range(int(iters)):
        gamma,alpha,beta = update_weights_pol_quadr(T, X, gamma, alpha, beta, learning_rate)

        #Calculate cost for auditing purposes
        mse_ini,rmse_ini,x_hat = cost_function_pol_quadr(T, X, gamma, alpha, beta)
        cost_history.append(rmse_ini)
        
        #Checking for the tolerance of the error
        tol_rmse = np.abs(rmse_ini-rmse_fim)
        tol_mse = np.abs(mse_ini-mse_fim)
        if tol_rmse < 1e-10:
            break
        mse_fim=mse_ini
        rmse_fim=rmse_ini
        
        # Log Progress
        if i % space_inter == 0:
            print ("iter={:d}  gamma={:.2f}  alpha={:.2f}    beta={:.4f}    MSE={:.2}     RMSE={:.2}".format(i,gamma, alpha, beta, mse_fim, rmse_fim))
            plt.scatter(T,X)
            plt.plot(T,x_hat,c='red')
            plt.show()
    return rmse_fim, gamma, alpha, beta, cost_history, i

# %% [markdown]
# ## KICK1

# %% [markdown]
# ### Fitting Z
# Aumentamos o número de interações do nosso algoritmo para que realmente encontrássemos uma função polinomial, pois com o número inicial de interações estávamos encontrando somente uma reta

# %%
rmse3_K1_pol, gamma3_K1_pol, alpha3_K1_pol,beta3_K1_pol,cost_history3_K1_pol,end_inter3_K1_pol = fit_polinomial_quadr(T,Z1,gamma_inicial,alpha_inicial,beta_inicial,learning_rate,inters+1000000)
# Out:
# iter=0  gamma=0.00  alpha=0.00    beta=0.0024    MSE=0.014     RMSE=0.12
# iter=206000  gamma=0.07  alpha=-0.06    beta=0.1263    MSE=0.00019     RMSE=0.014
# iter=412000  gamma=0.14  alpha=-0.08    beta=0.1277    MSE=0.00019     RMSE=0.014
# iter=618000  gamma=0.19  alpha=-0.10    beta=0.1289    MSE=0.00019     RMSE=0.014
# iter=824000  gamma=0.24  alpha=-0.11    beta=0.1297    MSE=0.00019     RMSE=0.014

# %% [markdown]
# ### Fitting X

# %%
rmse1_K1_pol, gamma1_K1_pol, alpha1_K1_pol,beta1_K1_pol,cost_history1_K1_pol,end_inter1_K1_pol = fit_polinomial_quadr(T,X1,gamma_inicial,alpha_inicial,beta_inicial,learning_rate,inters+1000000)
# Out:
# iter=0  gamma=-0.00  alpha=-0.00    beta=-0.0146    MSE=0.59     RMSE=0.77
# iter=206000  gamma=-0.35  alpha=-2.85    beta=-0.2156    MSE=0.00081     RMSE=0.028
# iter=412000  gamma=0.11  alpha=-3.01    beta=-0.2057    MSE=0.00069     RMSE=0.026
# iter=618000  gamma=0.46  alpha=-3.13    beta=-0.1980    MSE=0.00062     RMSE=0.025
# iter=824000  gamma=0.74  alpha=-3.23    beta=-0.1920    MSE=0.00058     RMSE=0.024

# %% [markdown]
# ### Equações finais para Kick1 modelo de regressão polinomial

# %%
print('X = {:.2f} * t² + {:.2f} * t + {:.2f}'.format(gamma1_K1_pol,alpha1_K1_pol,beta1_K1_pol))
print('Y = {:.2f} * t + {:.2f}'.format(alpha2_K1_lin,beta2_K1_lin))
print('Z = {:.2f} * t² + {:.2f} * t + {:.2f}'.format(gamma3_K1_pol, alpha3_K1_pol,beta3_K1_pol))
print('Erros para Kick1 Polinomial: RMSE_X={:.3f}, RMSE_Y={:.3f}, RMSE_Z={:.3f}'.format(rmse1_K1_pol,rmse2_K1_lin,rmse3_K1_pol))
# Out:
# X = 0.95 * t² + -3.31 * t + -0.19
# Y = -2.98 * t + 2.10
# Z = 0.25 * t² + -0.12 * t + 0.13
# Erros para Kick1 Polinomial: RMSE_X=0.024, RMSE_Y=0.011, RMSE_Z=0.014

# %% [markdown]
# ## KICK2

# %% [markdown]
# ### Fitting Z

# %%
rmse3_K2_pol, gamma3_K2_pol, alpha3_K2_pol,beta3_K2_pol,cost_history3_K2_pol,end_inter3_K2_pol = fit_polinomial_quadr(T,Z2,gamma_inicial,alpha_inicial,beta_inicial,learning_rate,inters+1000000)
# Out:
# iter=0  gamma=0.00  alpha=0.00    beta=0.0048    MSE=0.056     RMSE=0.24
# iter=206000  gamma=-0.22  alpha=0.52    beta=0.1558    MSE=0.00025     RMSE=0.016
# iter=412000  gamma=-0.50  alpha=0.62    beta=0.1498    MSE=0.00021     RMSE=0.014
# iter=618000  gamma=-0.72  alpha=0.69    beta=0.1450    MSE=0.00018     RMSE=0.013
# iter=824000  gamma=-0.89  alpha=0.75    beta=0.1413    MSE=0.00017     RMSE=0.013

# %% [markdown]
# ### Fitting X

# %%
rmse1_K2_pol, gamma1_K2_pol, alpha1_K2_pol,beta1_K2_pol,cost_history1_K2_pol,end_inter1_K2_pol = fit_polinomial_quadr(T,X2,gamma_inicial,alpha_inicial,beta_inicial,learning_rate,inters+1000000)
# Out:
# iter=0  gamma=-0.00  alpha=-0.00    beta=-0.0073    MSE=0.15     RMSE=0.38
# iter=206000  gamma=-0.18  alpha=-1.41    beta=-0.1098    MSE=0.00027     RMSE=0.016
# iter=412000  gamma=0.04  alpha=-1.49    beta=-0.1050    MSE=0.00024     RMSE=0.016
# iter=618000  gamma=0.22  alpha=-1.55    beta=-0.1012    MSE=0.00023     RMSE=0.015
# iter=824000  gamma=0.35  alpha=-1.59    beta=-0.0983    MSE=0.00022     RMSE=0.015

# %% [markdown]
# ### Equações finais para Kick2 modelo de regressão polinomial

# %%
print('X = {:.2f} * t² + {:.2f} * t + {:.2f}'.format(gamma1_K2_pol,alpha1_K2_pol,beta1_K2_pol))
print('Y = {:.2f} * t + {:.2f}'.format(alpha2_K2_lin,beta2_K2_lin))
print('Z = {:.2f} * t² + {:.2f} * t + {:.2f}'.format(gamma3_K2_pol, alpha3_K2_pol,beta3_K2_pol))
print('Erros para Kick2 Polinomial: RMSE_X={:.3f}, RMSE_Y={:.3f}, RMSE_Z={:.3f}'.format(rmse1_K2_pol,rmse2_K2_lin,rmse3_K2_pol))
# Out:
# X = 0.45 * t² + -1.63 * t + -0.10
# Y = -2.98 * t + 2.10
# Z = -1.02 * t² + 0.80 * t + 0.14
# Erros para Kick2 Polinomial: RMSE_X=0.014, RMSE_Y=0.011, RMSE_Z=0.012

# %%
#eixos do kick1
X1_pred_pol=[]
X2_pred_pol=[]
Z1_pred_pol=[]
Z2_pred_pol=[]
for i in range(len(T_full)):
    X1_pred_pol.append((gamma1_K1_pol * (T_full[i]**2) +alpha1_K1_pol * T_full[i] + beta1_K1_pol))
    X2_pred_pol.append((gamma1_K2_pol * (T_full[i]**2) +alpha1_K2_pol * T_full[i] + beta1_K2_pol))
    Z1_pred_pol.append(gamma3_K1_pol * (T_full[i]**2) + alpha3_K1_pol * T_full[i] + beta3_K1_pol)
    Z2_pred_pol.append(gamma3_K2_pol * (T_full[i]**2) + alpha3_K2_pol * T_full[i] + beta3_K2_pol)
    if i==len(Y1_pred_lin)-1:
        break
        
        
#plotando a figura dos kicks para os eixos x e y --> Notar que os eixos estão invertidos!!!
fig=plt.figure()
fig.set_size_inches(12, 7)
ax=fig.add_subplot(1,1,1)
draw_pitch(ax,0.33)
plt.scatter(Y1, X1,label='kick1')
plt.scatter(Y2, X2,label='kick2')
plt.plot(Y1_pred_lin, X1_pred_pol,label='predict kick1')
plt.plot(Y2_pred_lin, X2_pred_pol,label='predict kick2')
ax.invert_yaxis()
plt.legend()
plt.show()

# %% [markdown]
# ## Extrapolando o Learning Rate

# %% [markdown]
# Selecionamos um modelo de regresão (para um eixo) para extrapolar a learning rate, pois os demais seguirão a mesma lógica.

# %% [markdown]
# ### Learning Rate Baixa ( lr  =  1e-5 )

# %%
rmse3_K2_pol_lrbaixa, gamma3_K2_pol_lrbaixa, alpha3_K2_pol_lrbaixa,beta3_K2_pol_lrbaixa,cost_history3_K2_pol_lrbaixa,end_inter3_K2_pol_lrbaixa = fit_polinomial_quadr(T,Z2,gamma_inicial,alpha_inicial,beta_inicial,1e-5,inters)
# Out:
# iter=0  gamma=0.00  alpha=0.00    beta=0.0000    MSE=0.059     RMSE=0.24
# iter=6000  gamma=0.00  alpha=0.01    beta=0.0268    MSE=0.046     RMSE=0.21
# iter=12000  gamma=0.00  alpha=0.01    beta=0.0505    MSE=0.036     RMSE=0.19
# iter=18000  gamma=0.00  alpha=0.01    beta=0.0715    MSE=0.029     RMSE=0.17
# iter=24000  gamma=0.00  alpha=0.02    beta=0.0899    MSE=0.023     RMSE=0.15

# %% [markdown]
# Podemos perceber que com um learning rate muito baixo, nosso algritmo passa todas as interações com mudanças muito incrementais no aprendizado.

# %% [markdown]
# ### Learning Rate Alta ( lr = 1 )

# %%
rmse3_K2_pol_lrlta, gamma3_K2_pol_lrlta, alpha3_K2_pol_lrlta,beta3_K2_pol_lrlta,cost_history3_K2_pol_lrlta,end_inter3_K2_pol_lrlta = fit_polinomial_quadr(T,Z2,gamma_inicial,alpha_inicial,beta_inicial,1,inters)
# Out:
# iter=0  gamma=0.02  alpha=0.09    beta=0.4756    MSE=0.066     RMSE=0.26
# iter=6000  gamma=1882764748733433780890833876897626224828934290327341171662113286724101369738506315124806366008808239843634178736353734939911360188111666309965729615064981332557824.00  alpha=8222624274844142117906894271103465804455608237108532738344392022072266190278741729055401085689063305044404112199700904861151967254199754339522494061385561436848128.00    beta=46532443757656541888939632269874178047372987081487510400359777487721415439838753077385239623258017465686246333842986503181023579520149531343355288811891964979970048.0000    MSE=inf     RMSE=inf
# <ipython-input-31-09d15a133199>:9: RuntimeWarning: overflow encountered in double_scalars
#   total_error += (X[i] - x_hat )**2
# <ipython-input-31-09d15a133199>:46: RuntimeWarning: invalid value encountered in double_scalars
#   tol_rmse = np.abs(rmse_ini-rmse_fim)
# ...

# %% [markdown]
# Já para um learning rate muito alto, nosso algoritmo se perde e dá overflow nos parâmetros

# %% [markdown]
# # Modelos aprendidos

# %%
#plotando a figura dos kicks para os eixos x e y --> Notar que os eixos estão invertidos!!!
fig=plt.figure()
fig.set_size_inches(12, 7)
ax=fig.add_subplot(1,1,1)
draw_pitch(ax,0.33)
plt.scatter(Y1, X1,label='kick1')
plt.scatter(Y2, X2,label='kick2')
plt.plot(Y1_pred_lin, X1_pred_lin,label='linear kick1',linestyle='--')
plt.plot(Y2_pred_lin, X2_pred_lin,label='linear kick2',linestyle='--')
plt.plot(Y1_pred_lin, X1_pred_pol,label='polinomial kick1')
plt.plot(Y2_pred_lin, X2_pred_pol,label='polinomial kick2')
ax.invert_yaxis()
plt.legend()
plt.show()

# %%
fig = plt.figure()
fig.set_size_inches(12, 12)
ax = plt.axes(projection="3d")
ax.scatter3D(X1,Y1, Z1,label='kick1')
ax.scatter3D(X2,Y2, Z2,label='kick2')
ax.plot3D(X1_pred_lin,Y1_pred_lin,Z1_pred_lin,label='linear kick1',linestyle='--')
ax.plot3D(X2_pred_lin,Y2_pred_lin,Z2_pred_lin,label='linear kick2',linestyle='--')
ax.plot3D(X1_pred_pol,Y1_pred_lin,Z1_pred_pol,label='polinomial kick1')
ax.plot3D(X2_pred_pol,Y2_pred_lin,Z2_pred_pol,label='polinomial kick2')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
ax.view_init(30, 785)
plt.xlim([3, -3])
plt.show()

# %%
# ANALISANDO OS EIXOS KICK 1

fig, axs = plt.subplots(2, 1)
fig.set_size_inches(12, 7)
# Axis 1
axs[0].scatter(Y1, X1,label='kick1')
axs[0].scatter(Y2, X2,label='kick2')
axs[0].plot(Y1_pred_lin, X1_pred_lin,label='linear kick1',linestyle='--')
axs[0].plot(Y2_pred_lin, X2_pred_lin,label='linear kick2',linestyle='--')
axs[0].plot(Y1_pred_lin, X1_pred_pol,label='polinomial kick1')
axs[0].plot(Y2_pred_lin, X2_pred_pol,label='polinomial kick2')
axs[0].set(xlabel='y', ylabel='X')
axs[0].set_title("DIREÇÃO NO GOL")
axs[0].legend()
axs[0].invert_yaxis()
# Axis 2
axs[1].scatter(Y1, Z1,label='kick1')
axs[1].scatter(Y2, Z2,label='kick2')
axs[1].plot(Y1_pred_lin, Z1_pred_lin,label='linear kick1',linestyle='--')
axs[1].plot(Y2_pred_lin, Z2_pred_lin,label='linear kick2',linestyle='--')
axs[1].plot(Y1_pred_lin, Z1_pred_pol,label='polinomial kick1')
axs[1].plot(Y2_pred_lin, Z2_pred_pol,label='polinomial kick2')
axs[1].set(xlabel='y', ylabel='Z')
axs[1].set_title("ALTURA DOS CHUTES")
axs[1].legend()



fig.tight_layout()

# %%
print('Erros para Kick1 Linear: RMSE_X={:.3f}, RMSE_Y={:.3f}, RMSE_Z={:.3f}'.format(rmse1_K1_lin,rmse2_K1_lin,rmse3_K1_lin))
print('Erros para Kick2 Linear: RMSE_X={:.3f}, RMSE_Y={:.3f}, RMSE_Z={:.3f}'.format(rmse1_K2_lin,rmse2_K2_lin,rmse3_K2_lin))
print('Erros para Kick1 Polinomial: RMSE_X={:.3f}, RMSE_Y={:.3f}, RMSE_Z={:.3f}'.format(rmse1_K1_pol,rmse2_K1_lin,rmse3_K1_pol))
print('Erros para Kick2 Polinomial: RMSE_X={:.3f}, RMSE_Y={:.3f}, RMSE_Z={:.3f}'.format(rmse1_K2_pol,rmse2_K2_lin,rmse3_K2_pol))
# Out:
# Erros para Kick1 Linear: RMSE_X=0.027, RMSE_Y=0.011, RMSE_Z=0.014
# Erros para Kick2 Linear: RMSE_X=0.016, RMSE_Y=0.011, RMSE_Z=0.017
# Erros para Kick1 Polinomial: RMSE_X=0.024, RMSE_Y=0.011, RMSE_Z=0.014
# Erros para Kick2 Polinomial: RMSE_X=0.014, RMSE_Y=0.011, RMSE_Z=0.012

# %% [markdown]
# Percebemos que os modelos de regressão polinomial se saíram melhor em relação ao erro RMSE, principalmente para o eixo Z se comparado com os modelos de regressão linear. Movemos a conclusão do trabalho para o início, para facilitar a correção.
